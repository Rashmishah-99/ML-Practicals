# %% [markdown]
# Exercise 1: K-Nearest Neighbor
#
# Let us implement the algorithm with the help of the 'Mobile.csv' dataset.
#
# It contains data about customers “Age”, “EstimatedSalary”, “Purchased” .
#
# Download the dataset from the shared folder.
#
#
# Predict if the customer will purchase a mobile or not.

# %% [markdown]
# Load data : mobile.csv

# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../ML Practicals/mobile.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              400 non-null    int64
#  1   EstimatedSalary  400 non-null    int64
#  2   Purchased        400 non-null    int64
# dtypes: int64(3)
# memory usage: 9.5 KB

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
df.tail()
# Out:
#      Age  EstimatedSalary  Purchased
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1

# %%
df["Purchased"].unique()
# Out:
# array([0, 1])

# %%
df.isna().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
purchased_data = df[["Age", "EstimatedSalary", "Purchased"]][df["Purchased"]==1]
purchased_data
# Out:
#      Age  EstimatedSalary  Purchased
# 7     32           150000          1
# 16    47            25000          1
# 17    45            26000          1
# 18    46            28000          1
# 19    48            29000          1
# ..   ...              ...        ...
# 393   60            42000          1
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 399   49            36000          1
#
# [143 rows x 3 columns]

# %%
not_purchased_data = df[["Age", "EstimatedSalary", "Purchased"]][df["Purchased"]==0]
not_purchased_data
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 377   42            53000          0
# 380   42            64000          0
# 387   39            71000          0
# 394   39            59000          0
# 398   36            33000          0
#
# [257 rows x 3 columns]

# %%
plt.scatter(purchased_data["Age"], purchased_data["EstimatedSalary"], c='green')
plt.scatter(not_purchased_data["Age"], not_purchased_data["EstimatedSalary"], c='red')

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
df["Age"].max()
# Out:
# np.int64(60)

# %%
df["Age"].min()
# Out:
# np.int64(18)

# %%
df["EstimatedSalary"].max()
# Out:
# np.int64(150000)

# %%
df["EstimatedSalary"].min()
# Out:
# np.int64(15000)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
features_to_scale = ["Age", "EstimatedSalary"]
scaled_values = scaler.fit_transform(df[features_to_scale])

# %%
df["norm_age"] = scaled_values[:,0]
df["norm_salary"] = scaled_values[:,1]

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased  norm_age  norm_salary
# 0     19            19000          0  0.023810     0.029630
# 1     35            20000          0  0.404762     0.037037
# 2     26            43000          0  0.190476     0.207407
# 3     27            57000          0  0.214286     0.311111
# 4     19            76000          0  0.023810     0.451852
# ..   ...              ...        ...       ...          ...
# 395   46            41000          1  0.666667     0.192593
# 396   51            23000          1  0.785714     0.059259
# 397   50            20000          1  0.761905     0.037037
# 398   36            33000          0  0.428571     0.133333
# 399   49            36000          1  0.738095     0.155556
#
# [400 rows x 5 columns]

# %%
df["norm_age"].min()
# Out:
# np.float64(0.0)

# %%
df["norm_age"].max()
# Out:
# np.float64(0.9999999999999998)

# %%
X = df[["norm_age", "norm_salary"]]
y = df[["Purchased"]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
print("Shape of X_train:", X_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (320, 2)
# Shape of y_train: (320, 1)
# Shape of X_test: (80, 2)
# Shape of y_test: (80, 1)

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=5, metric="euclidean")
model.fit(X_train, y_train)
# Out:
# c:\Users\rs889\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(metric='euclidean')

# %%
model.score(X_train, y_train) * 100
# Out:
# 91.875

# %%
model.score(X_test, y_test) * 100
# Out:
# 95.0

# %% [markdown]
# ## Exercise 2: SVM for classification
#
# Consider the Iris dataset which provides measurements of sepal length, sepal width, petal length, and petal width for 50 flowers from each of 3 species. Total rows are 150.
#
#
# Create Binary Class SVM model
# Reading input from csv file (iris.csv)
# Do Feature Engineering
# Create a new column in the dataframe (v_nv), that distinguishes the species - 'versicolor'(marked by 0) from rest.
# Build Model
# Visualize Model using mlxtend
#
# Create Multi Class SVM model
# Reading input from csv file (iris.csv)
# Do Feature Engineering
# Encode the species column with numerical values. And replace label 'setosa' with '0', 'versicolor' with '1' and 'virginica' with '2'.
# Build Multiclass Model using SVM
# Visualize Model using mlxtend

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
iris_data = pd.read_csv('../ML Practicals/iris.csv')
iris_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
iris_data['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
v_nv_fn = lambda x:0 if x=="Iris-versicolor" else 1
iris_data["v_nv"] = iris_data["Species"].apply(v_nv_fn)
iris_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  v_nv
# 0       Iris-setosa     1
# 1       Iris-setosa     1
# 2       Iris-setosa     1
# 3       Iris-setosa     1
# 4       Iris-setosa     1
# ..              ...   ...
# 145  Iris-virginica     1
# 146  Iris-virginica     1
# 147  Iris-virginica     1
# 148  Iris-virginica     1
# 149  Iris-virginica     1
#
# [150 rows x 7 columns]

# %%
import seaborn as sns
sns. pairplot(iris_data,
x_vars = "PetalLengthCm",y_vars="PetalWidthCm",hue="v_nv", height=5)

# %%
from sklearn.svm import SVC
X = iris_data[["PetalLengthCm", "PetalWidthCm"]]
y = iris_data["v_nv"]
model = SVC()
model.fit(X, y)
model.score(X, y) * 100
# Out:
# 95.33333333333334

# %%
from mlxtend.plotting import plot_decision_regions
features = np.array(X)
target = np.array(y)
plot_decision_regions(features, target, clf=model)
plt.xlabel("Petal length")
plt.ylabel("Petal width")
plt.title("Decision Boundary of SVM on iris data")
# Out:
# c:\Users\rs889\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# Text(0.5, 1.0, 'Decision Boundary of SVM on iris data')

# %%
pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.24.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.16.3 in c:\users\rs889\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.17.0)
# Requirement already satisfied: numpy>=2.3.5 in c:\users\rs889\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (2.3.5)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\rs889\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\rs889\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\users\rs889\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\rs889\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rs889\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\rs889\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rs889\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rs889\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\rs889\appdata\roaming\python\python312\site-packages (from matplotlib>=3.10.8->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\rs889\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\rs889\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rs889\appdata\roaming\python\python312\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rs889\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rs889\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\rs889\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\rs889\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# Downloading mlxtend-0.24.0-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 1.0 MB/s eta 0:00:01
#    ------------------------------ --------- 1.0/1.4 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 1.8 MB/s  0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.24.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# 2. Binary Classification

# %%
iris_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  v_nv
# 0       Iris-setosa     1
# 1       Iris-setosa     1
# 2       Iris-setosa     1
# 3       Iris-setosa     1
# 4       Iris-setosa     1
# ..              ...   ...
# 145  Iris-virginica     1
# 146  Iris-virginica     1
# 147  Iris-virginica     1
# 148  Iris-virginica     1
# 149  Iris-virginica     1
#
# [150 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
iris_data["Species"] = le.fit_transform(iris_data["Species"])
iris_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species  \
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
#      v_nv
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# ..    ...
# 145     1
# 146     1
# 147     1
# 148     1
# 149     1
#
# [150 rows x 7 columns]

# %%
X = iris_data[["PetalLengthCm", "PetalWidthCm"]]
y = iris_data["Species"]
model = SVC()
model.fit(X, y)
# Out:
# SVC()

# %%
from mlxtend.plotting import plot_decision_regions
features = np.array(X)
target = np.array(y)
plot_decision_regions(features, target, clf=model)
plt.xlabel("Petal length")
plt.ylabel("Petal width")
plt.title("Multiclass classification on iris using SVM")
# Out:
# c:\Users\rs889\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# Text(0.5, 1.0, 'Multiclass classification on iris using SVM')
